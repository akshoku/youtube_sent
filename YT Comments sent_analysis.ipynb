# %%
import creds #python file containing api key

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

DEVELOPER_KEY = creds.api #api imported from creds
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_video_comments(video_id):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)
    comments = []
    try:
        results = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            textFormat="plainText"
        ).execute()

        while results:
            for item in results["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)

            if "nextPageToken" in results:
                nextPageToken = results["nextPageToken"]
                results = youtube.commentThreads().list(
                    part="snippet",
                    videoId=video_id,
                    textFormat="plainText",
                    pageToken=nextPageToken
                ).execute()
            else:
                break

    except HttpError as error:
        print(f"An HTTP error {error.resp.status} occurred: {error.content}")

    return comments

def get_comments_for_videos(video_ids):
    comments_dict = {}
    for video_id in video_ids:
        comments = get_video_comments(video_id)
        comments_dict[video_id] = comments
    return comments_dict

# Example usage
video_id = 'ZBxtq3RE3Tk' #My waves
#video_ids = ["VIDEO_ID_1", "VIDEO_ID_2", "VIDEO_ID_3"]
#comments_dict = get_comments_for_videos(video_ids)
#print(comments_dict)

comments = get_video_comments(video_id)
print(comments)
# Out:
# ['I will wait I will follow I will never be the same', 'My heavenly love all for you', '🐒🙏', 'Even a Tsunami is usually triggered by an earthquake. I gave it my best for too long. Please stay away', "I am just feels for comfortable to your songs albums you too you have so wonderful culture and you have real singer personality at all I feels of so innocent heart & mind strangers to you at least you're a miracle someone about of singers world but I am not so weak for myself if you love to me so I will be too if you not so why I will be try it.S.m.a.k", 'Gusnihidayat yang sayasayangkamu kokkamyjugasamasepertikehidupansayamohonmaafkepadakamuloveyu', 'I will wait I will follow I will never be the same', "Maybe you're born in the earth only for mine if we can't be add on together in that life so we will be try it over every born get on to be fry you & me always single alone  but  in our memory loving together so thirsty hunt in out mind oh come on darling let's do love for ever live on the life if come to me so I will be go with you where's will belong decided for you...s.m.a.k", "Good night my dear lovely sweetheart you're my love you're my heart ♥ I want to need all of your parts where's will belong can you tell me to that?", "I will wait I will follow I will never be the same my loves for you got on to that so wonders of the dreams how can be the child oh darling let's do something without conditional 5th of the hard Rock something about insults feels for my owned self.S.m.a.k", "How can pain be sweet, even for a while?\nHow come I'm full grown, yet feel like a child?\nHow can you control me with a single look?\nHow can I express these things in words or books?\n\nWhere language fails music speaks\nSo I came to sing you this song\nTell you I'll wait for you a hundred years\nLet me in, darlin', let me in\n\nAnd I will stand, waitin' for the dawn\nSlippin' through the closet space and time\nYou built a wall on my sandy shore\nBut my waves will open up the door\nOh, but my waves will open up the door\nHey, yeah-yeah-yeah\n\nI know you've been hurt, love can take its toll\nHow can we be sane, yet so out of control?\nI don't even think I ever made a choice\nTo live and die just on the promise of your voice\n\nWhere language fails music speaks\nSo I came to sing you this song\nTell you I'll wait for you a hundred years\nLet me in, darlin', let me in\n\nAnd I will stand, waitin' for the dawn\nSlippin' through the closet space and time\nYou built a wall on my sandy shore\nBut my waves will open up the door\nOh, but my waves will open up the door\nSinging\n\nI will wait\nI will follow\nI will never be the same\nI will wait\nI will follow\nI will never be the same\nI will wait\nI will follow\nI will never be the same\n\nI will wait\nI will follow\nI will never be the same", 'I will wait I will follow I will never be the same', 'I will wait I will follow I will never be the same', 'Sorry in choice able for you', 'Subahan Allah alhamdulillah get on to my loves all to you', 'I love you so much 💗 believe me you are so beautiful girl', "Luciana, It's been a while since I've searched for your music, although I still listen to what's available on my iTunes. I just wanted to say that through all the turmoil in the world the last two years I hope that you are happy and healthy! Please keep singing... it's as beautiful as ever.", 'عناق الزهور\nلبذرة الصباح طويل\nالسهول تتعرف\nعلى الوديان الخضراء\nكل شيء جميل جدا\nالطبيعه ووجه حبيبتي\nانتظر كل صباح\nيوم جميل\nلالمح هذا الجمال المشع\nمن الزهور\nومن وجه حبيبتي\nالذي أتمناه في كل امنيه\nفي كل اغنيه\nتعلمت كتابتها\nباشواقي كلها\nلوجه حبيبتي المشع\nكالنهار الطويل', 'This wonderful song just changed my life!!', 'احيانا تكون خطواتنا في السحاب', 'Luciana, your song and you are wonderful... 🌹🌹🌹🌹🌹🌹🌹🌹', 'Good  tok 🤫👸😍', 'I love you', 'in love with this song <3', 'Luciana zogbi is the most beautiful girl, ‘ve ever seen and such a beautiful voice \n\nCalm & relax !!', '😍🥰🥰🥰🥰🥰🥰🥰', '这首歌，很动听。', 'Thiss isss GOLLDDDDE ...

# %% [markdown]
# # Using TEXTBLOB FOR SENTIMENT ANALYSIS

# %%
from textblob import TextBlob

def analyze_sentiment(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity
    return sentiment # we return the sentiment between -1 and 1

# %%
def total_sent(comments):
    s = 0
    for ele in comments:
        s = s + analyze_sentiment(ele)
        
    sen = s/len(comments)
    return sen

# %%
senti = total_sent(comments)

# %%
print(senti)
# Out:
# 0.29756909180581664

# %%
def text_ans(sen):
    if sen>0:
        print('Positive')
    elif sen<0:
        print('Negetive')
    else:
        print('Neutral')

# %%
text_ans(senti)
# Out:
# Positive

# %% [markdown]
# Thus the majority of comments are positive

# %% [markdown]
# # Using NLTK FOR SENTIMENT ANALYSIS

# %%
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define the sentence to analyze
sentence = "I love this movie! It's so good."

# Perform sentiment analysis on the sentence
sentiment = sia.polarity_scores(sentence)

# Print the sentiment scores
print(sentiment)
# Out:
# {'neg': 0.0, 'neu': 0.327, 'pos': 0.673, 'compound': 0.8494}

# %%
def nltk_senti(text):
    sia = SentimentIntensityAnalyzer()
    sentiment = sia.polarity_scores(text)
    return sentiment['compound']

# %%
def total_sent(comments):
    s = 0
    for ele in comments:
        s = s + nltk_senti(ele)
        
    sen = s/len(comments)
    return sen

# %%
sentiment = total_sent(comments)
print(sentiment)
# Out:
# 0.38383704115684114

# %%
def text_ans(sen):
    if sen>0:
        print('Positive')
    elif sen<0:
        print('Negetive')
    else:
        print('Neutral')

# %%
text_ans(sentiment)
# Out:
# Positive

# %% [markdown]
# Thus the majority of comments are positive
